# %%
import torchaudio 
from IPython.display import Audio

# %%
output_dir = "/home/bltang/work/publication/demo_site/TSELM.demo/demo/1"
sr = 16000

# %%
def save_audio(name, audio, start, end):
    audio = audio[:, sr * start: sr * end]
    Audio(audio, rate = sr)
    torchaudio.save(f"{output_dir}/{name}", audio, 16000)

# %%
## TSELM_L
audio_name = "tselm_l.wav"
second = 6
audio, rate = torchaudio.load(f"/home/bltang/Downloads/1462-170138-0011_652-130726-0021.wav")
save_audio(audio_name, audio, 0, 6)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 5
#       3 second = 6
#       4 audio, rate = torchaudio.load(f"/home/bltang/Downloads/1462-170138-0011_652-130726-0021.wav")
# ----> 5 save_audio(audio_name, audio, 0, 6)
#
# Cell In[30], line 4, in save_audio(name, audio, start, end)
#       2 audio = audio[:, sr * start: sr * end]
#       3 Audio(audio, rate = sr)
# ----> 4 torchaudio.save(f"output_dir/{name}", audio, 16000)
#
# File ~/.local/lib/python3.8/site-packages/torchaudio/_backend/utils.py:313, in get_save_func.<locals>.save(uri, src, sample_rate, channels_first, format, encoding, bits_per_sample, buffer_size, backend, compression)
#     236 """Save audio data to file.
#     237
#     238 Note:
#    (...)
#     310
#     311 """
#     312 backend = dispatcher(uri, format, backend)
# --> 313 return backend.save(
#     314     uri, src, sample_rate, channels_first, format, encoding, bits_per_sample, buffer_size, compression
#     315 )
#
# File ~/.local/lib/python3.8/site-packages/torchaudio/_backend/ffmpeg.py:316, in FFmpegBackend.save(uri, src, sample_rate, channels_first, format, encoding, bits_per_sample, buffer_size, compression)
#     311 if not isinstance(compression, (torchaudio.io.CodecConfig, type(None))):
#     312     raise ValueError(
#     313         "FFmpeg backend expects non-`None` value for argument `compression` to be of ",
#     314         f"type `torchaudio.io.CodecConfig`, but received value of type {type(compression)}",
#     315     )
# --> 316 save_audio(
#     317     uri,
#     318     src,
#     319     sample_rate,
#     320     channels_first,
#     321     format,
#     322     encoding,
#     323     bits_per_sample,
#     324     buffer_size,
#     325     compression,
#     326 )
#
# File ~/.local/lib/python3.8/site-packages/torchaudio/_backend/ffmpeg.py:256, in save_audio(uri, src, sample_rate, channels_first, format, encoding, bits_per_sample, buffer_size, compression)
#     247 s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
#     248 s.add_audio_stream(
#     249     sample_rate,
#     250     num_channels=src.size(-1),
#    (...)
#     254     codec_config=compression,
#     255 )
# --> 256 with s.open():
#     257     s.write_audio_chunk(0, src)
#
# File ~/.local/lib/python3.8/site-packages/torio/io/_streaming_media_encoder.py:436, in StreamingMediaEncoder.open(self, option)
#     400 """Open the output file / device and write the header.
#     401
#     402 :py:class:`StreamingMediaEncoder` is also a context manager and therefore supports the
#    (...)
#     433     >>>     f.write_audio_chunk(...)
#     434 """
#     435 if not self._is_open:
# --> 436     self._s.open(option)
#     437     self._is_open = True
#     438 return self
#
# RuntimeError: Failed to open dst: output_dir/tselm_l.wav (No such file or directory)
# Exception raised from open at /__w/audio/audio/pytorch/audio/src/libtorio/ffmpeg/stream_writer/stream_writer.cpp:240 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x7f8ba44be897 in /home/bltang/.local/lib/python3.8/site-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x7f8ba446eb25 in /home/bltang/.local/lib/python3.8/site-packages/torch/lib/libc10.so)
# frame #2: torio::io::StreamingMediaEncoder::open(std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x4cf (0x7f8ad9d14bbf in /home/bltang/.local/lib/python3.8/site-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #3: <unknown function> + 0x3a87c (0x7f8abc91287c in /home/bltang/.local/lib/python3.8/site-packages/torio/lib/_torio_ffmpeg4.so)
# frame #4: <unknown function> + 0x32545 (0x7f8abc90a545 in /home/bltang/.local/lib/python3.8/site-packages/torio/lib/_torio_ffmpeg4.so)
# frame #5: PyCFunction_Call + 0x59 (0x5f58f9 in /usr/bin/python3)
# frame #6: _PyObject_MakeTpCall + 0x29e (0x5f64ce in /usr/bin/python3)
# frame #7: /usr/bin/python3() [0x50b4b3]
# frame #8: _PyEval_EvalFrameDefault + 0x5777 (0x570b67 in /usr/bin/python3)
# frame #9: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #10: _PyFunction_Vectorcall + 0x393 (0x5f5e83 in /usr/bin/python3)
# frame #11: _PyEval_EvalFrameDefault + 0x907 (0x56bcf7 in /usr/bin/python3)
# frame #12: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #13: _PyFunction_Vectorcall + 0x393 (0x5f5e83 in /usr/bin/python3)
# frame #14: _PyEval_EvalFrameDefault + 0x725 (0x56bb15 in /usr/bin/python3)
# frame #15: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #16: _PyFunction_Vectorcall + 0x393 (0x5f5e83 in /usr/bin/python3)
# frame #17: _PyEval_EvalFrameDefault + 0x5777 (0x570b67 in /usr/bin/python3)
# frame #18: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #19: _PyFunction_Vectorcall + 0x393 (0x5f5e83 in /usr/bin/python3)
# frame #20: _PyEval_EvalFrameDefault + 0x5777 (0x570b67 in /usr/bin/python3)
# frame #21: _PyFunction_Vectorcall + 0x1b6 (0x5f5ca6 in /usr/bin/python3)
# frame #22: _PyEval_EvalFrameDefault + 0x725 (0x56bb15 in /usr/bin/python3)
# frame #23: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #24: PyEval_EvalCode + 0x27 (0x68ce77 in /usr/bin/python3)
# frame #25: /usr/bin/python3() [0x6005e4]
# frame #26: /usr/bin/python3() [0x5c4780]
# frame #27: _PyEval_EvalFrameDefault + 0x725 (0x56bb15 in /usr/bin/python3)
# frame #28: /usr/bin/python3() [0x5006a8]
# frame #29: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #30: /usr/bin/python3() [0x5006a8]
# frame #31: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #32: /usr/bin/python3() [0x5006a8]
# frame #33: /usr/bin/python3() [0x5042c6]
# frame #34: _PyEval_EvalFrameDefault + 0x907 (0x56bcf7 in /usr/bin/python3)
# frame #35: _PyFunction_Vectorcall + 0x1b6 (0x5f5ca6 in /usr/bin/python3)
# frame #36: _PyEval_EvalFrameDefault + 0x725 (0x56bb15 in /usr/bin/python3)
# frame #37: _PyFunction_Vectorcall + 0x1b6 (0x5f5ca6 in /usr/bin/python3)
# frame #38: _PyEval_EvalFrameDefault + 0x907 (0x56bcf7 in /usr/bin/python3)
# frame #39: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #40: _PyFunction_Vectorcall + 0x393 (0x5f5e83 in /usr/bin/python3)
# frame #41: /usr/bin/python3() [0x50ad5c]
# frame #42: PyObject_Call + 0x62 (0x5f5072 in /usr/bin/python3)
# frame #43: _PyEval_EvalFrameDefault + 0x1f2d (0x56d31d in /usr/bin/python3)
# frame #44: _PyEval_EvalCodeWithName + 0x26a (0x569dfa in /usr/bin/python3)
# frame #45: /usr/bin/python3() [0x50add0]
# frame #46: _PyEval_EvalFrameDefault + 0x1905 (0x56ccf5 in /usr/bin/python3)
# frame #47: /usr/bin/python3() [0x5006a8]
# frame #48: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #49: /usr/bin/python3() [0x5006a8]
# frame #50: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #51: /usr/bin/python3() [0x5006a8]
# frame #52: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #53: /usr/bin/python3() [0x5006a8]
# frame #54: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #55: /usr/bin/python3() [0x5006a8]
# frame #56: _PyEval_EvalFrameDefault + 0x212f (0x56d51f in /usr/bin/python3)
# frame #57: /usr/bin/python3() [0x5006a8]
# frame #58: <unknown function> + 0x7ef9 (0x7f8bb8da1ef9 in /usr/lib/python3.8/lib-dynload/_asyncio.cpython-38-x86_64-linux-gnu.so)
# frame #59: <unknown function> + 0x9083 (0x7f8bb8da3083 in /usr/lib/python3.8/lib-dynload/_asyncio.cpython-38-x86_64-linux-gnu.so)
# frame #60: _PyObject_MakeTpCall + 0x29e (0x5f64ce in /usr/bin/python3)
# frame #61: /usr/bin/python3() [0x5ff183]
# frame #62: /usr/bin/python3() [0x5c4667]
# frame #63: PyVectorcall_Call + 0x58 (0x5f5638 in /usr/bin/python3)

# %%
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## SPEX_PLUS
audio_name = "spex.wav"
sr = 16000
audio, rate = torchaudio.load(f"/home/bltang/Downloads/1462-170138-0011_652-130726-0021 (1).wav")

# %%
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## Ground Truth
name = "target.wav"
audio, rate = torchaudio.load(f"/home/bltang/work/publication/data/libri2mix_dev/s1/1462-170138-0011_652-130726-0021.wav")
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## Reference Audio
audio, rate = torchaudio.load(f"/home/bltang/work/publication/data/libri2mix_dev/aux_s1/1462-170138-0000_652-130726-0018.wav")
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## TSELM-L-Hybrid
audio, rate = torchaudio.load(f"/home/bltang/work/publication/data/tselm_l_hybrid/audio/1462-170138-0011_652-130726-0021.wav")
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## Continuous-WavLM-L6
audio, rate = torchaudio.load(f"/home/bltang/work/publication/data/continuous_wavlm_l6/output/1462-170138-0011_652-130726-0021.wav")
Audio(audio[:,:6 * sr], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
